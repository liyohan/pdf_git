# %%
import jieba
import pandas as pd
import numpy as np
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
filr = pd.read_csv('model.csv')

# %%
filr
# Out:
#       Unnamed: 0     adv   bottom  cod     doctop             fontname  \
# 0              0   0.534   52.162    0     51.202                Arial
# 1              1   0.217   52.200    1     51.240       ABCDEE+Calibri
# 2              2   6.643   54.052    2     44.092                Arial
# 3              3   5.280   85.129    3     74.569            ABCDEE+宋体
# 4              4   5.280  100.749    4     90.189            ABCDEE+宋体
# 5              5   5.280  116.349    5    105.789            ABCDEE+宋体
# 6              6   5.280  131.949    6    121.389            ABCDEE+宋体
# 7              7   5.280  147.549    7    136.989            ABCDEE+宋体
# 8              8  15.960  173.510    8    157.550            ABCDEE+黑体
# 9              9  14.040  203.840    9    189.800            ABCDEE+黑体
# 10            10  14.040  235.040   10    221.000            ABCDEE+宋体
# 11            11  14.040  235.040   10    221.000            ABCDEE+宋体
# ...

# %%
data = filr.loc[filr['text']!=' ']
data = data['text']
data
# Out:
# 0                                             0
# 2                                           B0
# 8                              开远市兴远开发投资集团有限公司
# 9                                     公司债券年度报告
# 10                                        （2020
# 11                                          年）
# 24                                     二〇二一年四月
# 27                 开远市兴远开发投资集团有限公司公司债券年度报告（2020
# 28                                          年）
# 29                                        重要提示
# 30        本公司董事、高级管理人员已对年度报告签署书面确认意见。公司监事会（如有）已
# 31                  对年度报告提出书面审核意见，监事已签署书面确认意见。
# 33        本公司及全体董事、监事、高级管理人员保证年度报告内容的真实、准确、完整，不
# 34               存在虚假记载、误导性陈述或重大遗漏，并承担相应的法律责任。
# 37        北京兴华会计师事务所（特殊普通合伙）为本公司出具了标准无保留意见的审计报告
# 38                                           。
# 41                                           2
# 42                 开远市兴远开发投资集团有限公司公司债券年度报告（2020
# 43                                          年）
# 47                                      重大风险提示
# ...

# %%
data_str = data[30].strip() +data[31].strip()
data_str
# Out:
# '本公司董事、高级管理人员已对年度报告签署书面确认意见。公司监事会（如有）已对年度报告提出书面审核意见，监事已签署书面确认意见。'

# %%
data_s = jieba.lcut(data_str.strip())
data_s
# Out:
# ['本',
#  '公司',
#  '董事',
#  '、',
#  '高级',
#  '管理人员',
#  '已',
#  '对',
#  '年度报告',
#  '签署',
#  '书面',
#  '确认',
#  '意见',
#  '。',
#  '公司',
#  '监事会',
#  '（',
#  '如',
#  '有',
#  '）',
#  '已',
#  '对',
#  '年度报告',
#  '提出',
#  '书面',
#  '审核',
#  '意见',
#  '，',
#  '监事',
#  '已',
#  '签署',
#  '书面',
#  '确认',
#  '意见',
#  '。']

# %%
FreqDist(data_s)
# Out:
# FreqDist({'已': 3, '书面': 3, '意见': 3, '公司': 2, '对': 2, '年度报告': 2, '签署': 2, '确认': 2, '。': 2, '本': 1, ...})
