# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.model_selection import train_test_split
# Out:
# /home/sunday/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv('model.csv')
data
# Out:
#    Unnamed: 0    adv   bottom  cod  doctop        fontname  height  \
# 0           0  0.534   52.162    0  51.202           Arial    0.96
# 1           1  0.217   52.200    1  51.240  ABCDEE+Calibri    0.96
# 2           2  6.643   54.052    2  44.092           Arial    9.96
# 3           3  5.280   85.129    3  74.569       ABCDEE+宋体   10.56
# 4           4  5.280  100.749    4  90.189       ABCDEE+宋体   10.56
#
#    non_stroking_color object_type  page_number   size  stroking_color text  \
# 0                 0.2        char            1   0.96             0.2    0
# 1                 0.0        char            1   0.96             0.0
# 2                 0.2        char            1   9.96             0.2  B0
# 3                 0.0        char            1  10.56             0.0
# 4                 0.0        char            1  10.56             0.0
#
#       top  upright  width       x0       x1       y0       y1
# 0  51.202     True  0.534  504.940  505.474  789.758  790.718
# ...

# %%
data = data.loc[data['text']!=' ']
data
# Out:
#       Unnamed: 0     adv   bottom  cod     doctop        fontname  height  \
# 0              0   0.534   52.162    0     51.202           Arial    0.96
# 2              2   6.643   54.052    2     44.092           Arial    9.96
# 8              8  15.960  173.510    8    157.550       ABCDEE+黑体   15.96
# 9              9  14.040  203.840    9    189.800       ABCDEE+黑体   14.04
# 10            10  14.040  235.040   10    221.000       ABCDEE+宋体   14.04
# 11            11  14.040  235.040   10    221.000       ABCDEE+宋体   14.04
# 24            24  12.000  475.762   23    463.762       ABCDEE+宋体   12.00
# 27            27   9.000   52.869    0    885.789       ABCDEE+宋体    9.00
# 28            28   9.000   52.869    0    885.789       ABCDEE+宋体    9.00
# 29            29  12.000   96.872    2    926.792       ABCDEE+宋体   12.00
# 30            30  10.560  138.549    3    969.909       ABCDEE+宋体   10.56
# 31            31  10.560  161.949    4    993.309       ABCDEE+宋体   10.56
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3588 entries, 0 to 4284
# Data columns (total 21 columns):
# Unnamed: 0            3588 non-null int64
# adv                   3588 non-null float64
# bottom                3588 non-null float64
# cod                   3588 non-null int64
# doctop                3588 non-null float64
# fontname              3588 non-null object
# height                3588 non-null float64
# non_stroking_color    3588 non-null float64
# object_type           3588 non-null object
# page_number           3588 non-null int64
# size                  3588 non-null float64
# stroking_color        3588 non-null float64
# text                  3588 non-null object
# top                   3588 non-null float64
# upright               3588 non-null bool
# width                 3588 non-null float64
# x0                    3588 non-null float64
# x1                    3588 non-null float64
# y0                    3588 non-null float64
# ...

# %%
data['页眉/页尾'] = data['text'].apply(lambda x:1 if x.strip() in ['开远市兴远开发投资集团有限公司公司债券年度报告（2020','年）'] else 0)
# Out:
# /home/sunday/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#       Unnamed: 0     adv   bottom  cod     doctop        fontname  height  \
# 0              0   0.534   52.162    0     51.202           Arial    0.96
# 2              2   6.643   54.052    2     44.092           Arial    9.96
# 8              8  15.960  173.510    8    157.550       ABCDEE+黑体   15.96
# 9              9  14.040  203.840    9    189.800       ABCDEE+黑体   14.04
# 10            10  14.040  235.040   10    221.000       ABCDEE+宋体   14.04
# 11            11  14.040  235.040   10    221.000       ABCDEE+宋体   14.04
# 24            24  12.000  475.762   23    463.762       ABCDEE+宋体   12.00
# 27            27   9.000   52.869    0    885.789       ABCDEE+宋体    9.00
# 28            28   9.000   52.869    0    885.789       ABCDEE+宋体    9.00
# 29            29  12.000   96.872    2    926.792       ABCDEE+宋体   12.00
# 30            30  10.560  138.549    3    969.909       ABCDEE+宋体   10.56
# 31            31  10.560  161.949    4    993.309       ABCDEE+宋体   10.56
# ...

# %%
Xtrain, Ytrain, xtest, ytest = train_test_split(data[data.columns[:-1]],data['页眉/页尾'])

# %%
Xtrain
# Out:
#       Unnamed: 0     adv   bottom  cod     doctop        fontname  height  \
# 1475        1475  10.560   98.229    4  13558.389       ABCDEE+宋体   10.56
# 2321        2321   9.000   52.869    0  17724.189       ABCDEE+宋体    9.00
# 1425        1425  10.560  604.799   55  13223.039       ABCDEE+宋体   10.56
# 4140        4140   5.354  307.490   35  33131.810  ABCDEE+Calibri   10.56
# 3822        3822   5.354  404.570   49  30703.130  ABCDEE+Calibri   10.56
# 3994        3994   5.354   86.520    2  32068.920  ABCDEE+Calibri   10.56
# 2438        2438   5.280  545.639   50  18215.399       ABCDEE+宋体   10.56
# 2221        2221   5.280  408.579   40  17236.419       ABCDEE+宋体   10.56
# 3711        3711  10.560  467.619   61  29924.259       ABCDEE+宋体   10.56
# 1412        1412   5.354  584.710   51  13202.950  ABCDEE+Calibri   10.56
# 4046        4046   5.354  422.210   55  32404.610  ABCDEE+Calibri   10.56
# 3577        3577  10.560  228.549   22  28843.269       ABCDEE+宋体   10.56
# ...
